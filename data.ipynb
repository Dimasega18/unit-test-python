# %%
import pandas as pd
df = pd.read_csv('.\Persentase penduduk usia 25 Tahun keatas dengan pendidikan SMA .csv')

# %%
df_new = df.copy().iloc[3:,:].reset_index().iloc[:,1:8]
df_new
# Out:
#     Provinsi/Kabupaten/Kota Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# 0                      ACEH      46.93       47.72       48.61      42.05
# 1                  Simeulue      52.05       50.98       52.16         40
# 2              Aceh Singkil      42.18       38.35       39.57      38.77
# 3              Aceh Selatan       38.2       37.46       39.08       32.6
# 4             Aceh Tenggara      54.36       55.48       55.44      43.27
# ..                      ...        ...         ...         ...        ...
# 544                 Dogiyai      13.54       17.49       17.10       6.94
# 545              Intan Jaya      19.66       21.65       14.29       3.76
# 546                  Deiyai      20.16       15.54       18.52       2.27
# 547           Kota Jayapura      69.53       76.55       73.70      66.56
# 548               INDONESIA       41.3       42.06       42.62      34.87
#
#      Unnamed: 5  Unnamed: 6
# 0         42.91       44.57
# ...

# %%
df_laki = df_new.iloc[:,0:4]
df_laki['Jenis Kelamin'] = "Laki-laki"
df_laki.head(3)
# Out:
#   Provinsi/Kabupaten/Kota Unnamed: 1  Unnamed: 2  Unnamed: 3 Jenis Kelamin
# 0                    ACEH      46.93       47.72       48.61     Laki-laki
# 1                Simeulue      52.05       50.98       52.16     Laki-laki
# 2            Aceh Singkil      42.18       38.35       39.57     Laki-laki

# %%
df_laki_2021 = df_laki.rename(columns={'Unnamed: 1':'Persentase'}).iloc[:,[0,1,4]]
df_laki_2021['Tahun'] = "2021"
df_laki_2021.head(3)
# Out:
#   Provinsi/Kabupaten/Kota Persentase Jenis Kelamin Tahun
# 0                    ACEH      46.93     Laki-laki  2021
# 1                Simeulue      52.05     Laki-laki  2021
# 2            Aceh Singkil      42.18     Laki-laki  2021

# %%
df_laki_2022 = df_laki.rename(columns={'Unnamed: 2':'Persentase'}).iloc[:,[0,2,4]]
df_laki_2022['Tahun'] = "2022"
df_laki_2022.head(3)
# Out:
#   Provinsi/Kabupaten/Kota  Persentase Jenis Kelamin Tahun
# 0                    ACEH       47.72     Laki-laki  2022
# 1                Simeulue       50.98     Laki-laki  2022
# 2            Aceh Singkil       38.35     Laki-laki  2022

# %%
df_laki_2023 = df_laki.rename(columns={'Unnamed: 3':'Persentase'}).iloc[:,[0,3,4]]
df_laki_2023['Tahun'] = "2023"
df_laki_2023.head(3)
# Out:
#   Provinsi/Kabupaten/Kota  Persentase Jenis Kelamin Tahun
# 0                    ACEH       48.61     Laki-laki  2023
# 1                Simeulue       52.16     Laki-laki  2023
# 2            Aceh Singkil       39.57     Laki-laki  2023

# %%
df_perempuan = df_new.iloc[:,[0,4,5,6]]
df_perempuan['Jenis Kelamin'] = 'Perempuan'
df_perempuan.head(3)
# Out:
# C:\Users\dimas\AppData\Local\Temp\ipykernel_3996\2819873339.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_perempuan['Jenis Kelamin'] = 'Perempuan'
#   Provinsi/Kabupaten/Kota Unnamed: 4  Unnamed: 5  Unnamed: 6 Jenis Kelamin
# 0                    ACEH      42.05       42.91       44.57     Perempuan
# 1                Simeulue         40       40.43       42.67     Perempuan
# 2            Aceh Singkil      38.77       37.36       38.62     Perempuan

# %%
df_perempuan_2021 = df_perempuan.rename(columns={'Unnamed: 4':'Persentase'}).iloc[:,[0,1,4]]
df_perempuan_2021['Tahun'] = "2021"
df_perempuan_2021.head(3)
# Out:
#   Provinsi/Kabupaten/Kota Persentase Jenis Kelamin Tahun
# 0                    ACEH      42.05     Perempuan  2021
# 1                Simeulue         40     Perempuan  2021
# 2            Aceh Singkil      38.77     Perempuan  2021

# %%
df_perempuan_2022 = df_perempuan.rename(columns={'Unnamed: 5':'Persentase'}).iloc[:,[0,2,4]]
df_perempuan_2022['Tahun'] = "2022"
df_perempuan_2022.head(3)
# Out:
#   Provinsi/Kabupaten/Kota  Persentase Jenis Kelamin Tahun
# 0                    ACEH       42.91     Perempuan  2022
# 1                Simeulue       40.43     Perempuan  2022
# 2            Aceh Singkil       37.36     Perempuan  2022

# %%
df_perempuan_2023 = df_perempuan.rename(columns={'Unnamed: 6':'Persentase'}).iloc[:,[0,3,4]]
df_perempuan_2023['Tahun'] = "2023"
df_perempuan_2023.head(3)
# Out:
#   Provinsi/Kabupaten/Kota  Persentase Jenis Kelamin Tahun
# 0                    ACEH       44.57     Perempuan  2023
# 1                Simeulue       42.67     Perempuan  2023
# 2            Aceh Singkil       38.62     Perempuan  2023

# %%
df_new.head(5)
# Out:
#   Provinsi/Kabupaten/Kota Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# 0                    ACEH      46.93       47.72       48.61      42.05
# 1                Simeulue      52.05       50.98       52.16         40
# 2            Aceh Singkil      42.18       38.35       39.57      38.77
# 3            Aceh Selatan       38.2       37.46       39.08       32.6
# 4           Aceh Tenggara      54.36       55.48       55.44      43.27
#
#    Unnamed: 5  Unnamed: 6
# 0       42.91       44.57
# 1       40.43       42.67
# 2       37.36       38.62
# 3       29.16       34.83
# 4       46.46       47.54

# %%
import re
import string

nama = df_new['Provinsi/Kabupaten/Kota'].values
karakter_unik = string.punctuation
data = []
for x in nama :
    data.append(bool(re.search('[!"#$%&\'()*+,-\./:;<=>?@[\\]^_`{|}~]',x)))
    
nama_unik = df_new.loc[data]

kabupatenkota_unik = nama_unik.loc[~(nama_unik['Provinsi/Kabupaten/Kota'] == 'KEP. BANGKA BELITUNG' )]

provinsi_unik = nama_unik.loc[(nama_unik['Provinsi/Kabupaten/Kota'] == 'KEP. BANGKA BELITUNG' )]

# %%
provinsi = [True if x.isupper() else False for x in df_new['Provinsi/Kabupaten/Kota']]
df_new.loc[provinsi]._append(provinsi_unik,ignore_index=True).drop_duplicates()
# Out:
#    Provinsi/Kabupaten/Kota Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# 0                     ACEH      46.93       47.72       48.61      42.05
# 1           SUMATERA UTARA      51.38       54.36       55.75       47.5
# 2           SUMATERA BARAT      43.74       45.32       46.08      44.97
# 3                     RIAU      46.39       45.76       45.75      43.04
# 4                    JAMBI      39.74       40.53       41.37      33.73
# 5         SUMATERA SELATAN      37.94       38.77       40.17      32.99
# 6                 BENGKULU      41.64       42.62       44.50      37.43
# 7                  LAMPUNG      33.72       34.88       36.15      28.77
# 8     KEP. BANGKA BELITUNG      37.52       40.76       40.75      33.58
# 9           KEPULAUAN RIAU      60.43       60.73       58.08       59.2
# 10             DKI JAKARTA      69.07       72.68       72.71      59.76
# 11              JAWA BARAT      40.99       41.24       41.24      33.12
# ...

# %%
df_new.shape
# Out:
# (549, 7)

# %%
kabupatenkota_unik
# Out:
#                         Provinsi/Kabupaten/Kota Unnamed: 1  Unnamed: 2  \
# 30                          Toba Samosir / Toba      56.34       65.17
# 165                                 Kep. Seribu      41.99       47.55
# 416                                   Toli-Toli      38.16       36.10
# 419                                Tojo Una-Una      27.27       28.34
# 479                   Mamuju Utara / Pasangkayu      34.63       35.28
# 482  Maluku Tenggara Barat / Kepulauan Tanimbar      45.24       44.59
#
#      Unnamed: 3 Unnamed: 4  Unnamed: 5  Unnamed: 6
# 30        65.02       59.2       62.11       62.03
# 165       44.71      33.56       41.45       37.97
# 416       36.73      31.54       31.83       31.81
# 419       28.30       25.7       28.41       31.13
# 479       35.36      29.74       34.04       34.11
# 482       44.16      44.53       43.03       43.16

# %%
kota_kab = [True if x.istitle() else False for x in df_new['Provinsi/Kabupaten/Kota']]
x = df_new[kota_kab]._append(kabupatenkota_unik,ignore_index=True)
x.drop_duplicates()
# Out:
#     Provinsi/Kabupaten/Kota Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# 0                  Simeulue      52.05       50.98       52.16         40
# 1              Aceh Singkil      42.18       38.35       39.57      38.77
# 2              Aceh Selatan       38.2       37.46       39.08       32.6
# 3             Aceh Tenggara      54.36       55.48       55.44      43.27
# 4                Aceh Timur      33.47       32.20       32.36      28.85
# ..                      ...        ...         ...         ...        ...
# 508                  Puncak       8.81        8.53        4.66       4.54
# 509                 Dogiyai      13.54       17.49       17.10       6.94
# 510              Intan Jaya      19.66       21.65       14.29       3.76
# 511                  Deiyai      20.16       15.54       18.52       2.27
# 512           Kota Jayapura      69.53       76.55       73.70      66.56
#
#      Unnamed: 5  Unnamed: 6
# 0         40.43       42.67
# ...

# %%
# Out:
# 0
